# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhleenkaursaini/UCS420/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assingment 1.1: WAP to print your name three times.

# %%
print ("Prabhleen")
print ("Prabhleen")
print ("Prabhleen")
# Out:
# Prabhleen
# Prabhleen
# Prabhleen

# %% [markdown]
# Assingment 2.1: WAP to add three numbers and print the result.

# %%
a=10
b=20
c=30
d=a+b+c
print (d)
# Out:
# 60

# %% [markdown]
# Assingment 2.2: WAP to concatinate three strings and print the result.

# %%
a="Cognitive"
b="Computing"
c="Lab"
d=a+" "+b+" "+c
print (d)
# Out:
# Cognitive Computing Lab

# %% [markdown]
# Assingment 4.1: WAP to print the table of 7, 9.

# %%
for i in range (1,11):
  print ("7 x",i,"=",7*i)

for i in range (1,11):
  print ("9 x",i,"=",9*i)
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# Assingment 4.2: WAP to print the table of n and n is given by user.

# %%
n = int(input("Enter a number: "))
for i in range (1,11):
  print (n,"x",i,"=",n*i)
# Out:
# Enter a number: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# Assingment 4.3: WAP to add all the numbers from 1 to n and n is given by user.

# %%
n = int(input("Enter a number: "))
sum = 0
for i in range (1,n+1):
  sum = sum + i
print ("Sum is: ", sum)
# Out:
# Enter a number: 5
# Sum is:  15

# %% [markdown]
# Assingment 5.1: WAP to find max amoung three numbers and input from user. [Try max() function]

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
m = max(a,b,c)
print ("Maximum number is: ", m)
# Out:
# Enter first number: 4
# Enter second number: 7
# Enter third number: 3
# Maximum number is:  7

# %% [markdown]
# Assingment 5.2: WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user.

# %%
n = int(input("Enter a number: "))
sum = 0
for i in range (1,n+1):
  if (i%7==0 and i%9==0):
    sum = sum + i
print ("Sum is: ", sum)
# Out:
# Enter a number: 99
# Sum is:  63

# %% [markdown]
# Assingment 5.3: WAP to add all prime numbers from 1 to n and n is given by the user.

# %%
n = int(input("Enter a number: "))
sum = 0
for i in range (2, n+1):
  prime=True
  for j in range (2, i):
    if (i%j==0):
      prime=False
      break
  if (prime==True):
    sum = sum + i
print ("Sum is: ", sum)
# Out:
# Enter a number: 30
# Sum is:  129

# %% [markdown]
# Assingment 6.1: WAP using function that add all odd numbers from 1 to n, n is given by the user.

# %%
def AddOdd(n):
  s=0
  for i in range(1, n+1):
    if i % 2 != 0:
      s=s+i
  return s

# %% [markdown]
# Assingment 6.2: WAP using function that add all prime numbers from 1 to n, n given by the user.

# %%
def IsPrime(n):
  if n<2:
    return 0
  for i in range(2,n):
    if n%i==0:
      return 0
  return 1
def AddPrime(n):
  s=0
  for i in range(1, n+1):
    if IsPrime(i):
      s=s+i
  return s

n=int(input("Enter a number: "))
print("Sum of prime numbers: ", AddPrime(n))
# Out:
# Enter a number: 55
# Sum of prime numbers:  381

# %% [markdown]
# Strings

# %% [markdown]
# 8.1 Indexing in string

# %%
var = 'Indexing'
print ("var: ", var)
print ("var[0]: ", var[0])
print ("var[1:5]: ", var[1:5])
print ("var[:-5]: ", var[:-5])
# Out:
# var:  Indexing
# var[0]:  I
# var[1:5]:  ndex
# var[:-5]:  Ind

# %% [markdown]
# 8.2 String length, upper, lower

# %%
var = 'Indexing'
print ("String: ", var)
print ("Length: ", len(var))
print ("Upper: ", var.upper())
print ("Lower: ", var.lower())
# Out:
# String:  Indexing
# Length:  8
# Upper:  INDEXING
# Lower:  indexing

# %% [markdown]
# 8.3 String formatting

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
price=float(input("Enter the item price: "))
s="\nYour name is %s, age is %d and item price is %f" %(name.upper(),age,price)
print (s)
# Out:
# Enter your name: Prabhleen
# Enter your age: 20
# Enter the item price: 56
#
# Your name is PRABHLEEN, age is 20 and item price is 56.000000

# %% [markdown]
# 8.4 String in Triple Quotes

# %%
para_str = """This is a long string that is made up of
several lines and non-printable characters.
"""
print (para_str)
# Out:
# This is a long string that is made up of
# several lines and non-printable characters.

# %% [markdown]
# 8.5 String strip

# %%
var =" Hello  World   "
print("String: ", var)
print("Length: ", len(var))
print("var strip: ", var.strip())
print("Length of var after strip: ", len(var.strip()))
# Out:
# String:   Hello  World
# Length:  16
# var strip:  Hello  World
# Length of var after strip:  12

# %% [markdown]
# 8.6 String split

# %%
var =" Hello,   World    "
print("String: ", var)
print("Length: ", len(var))
print("var split: ", var.split())
print("var split: ", var.split(' '))
print("var split: ", var.split(','))
print("var split: ", var.strip().split(','))
# Out:
# String:   Hello,   World
# Length:  19
# var split:  ['Hello,', 'World']
# var split:  ['', 'Hello,', '', '', 'World', '', '', '', '']
# var split:  [' Hello', '   World    ']
# var split:  ['Hello', '   World']

# %% [markdown]
# 8.7 Count in string

# %%
var=" Hello World    "
print ("String: ", var)
print ("Count of ' ': ", var.count(' '))
print ("Count of 'l': ", var.count('l'))
print ("Count of 'o': ", var.count('o'))
# Out:
# String:   Hello World
# Count of ' ':  6
# Count of 'l':  3
# Count of 'o':  2

# %% [markdown]
# 8.8 Reverse a String

# %%
var="Hello World"
print ("String: ", var)
print ("var[::1]: ", var[::1])
print ("var[::2]: ", var[::2])
print ("var[::-1]: ", var[::-1])
print ("var[::-2]: ", var[::-2])
var=var[::-1]
print ("var after reverse: ", var)
# Out:
# String:  Hello World
# var[::1]:  Hello World
# var[::2]:  HloWrd
# var[::-1]:  dlroW olleH
# var[::-2]:  drWolH
# var after reverse:  dlroW olleH

# %% [markdown]
# 8.9 Palindrome

# %%
s1="Hello World"
s2="level"
s3="madam"
s4="teacher"
print ("s1: ", s1==s1[::-1])
print ("s2: ", s2==s2[::-1])
print ("s3: ", s3==s3[::-1])
print ("s4: ", s4==s4[::-1])
# Out:
# s1:  False
# s2:  True
# s3:  True
# s4:  False
