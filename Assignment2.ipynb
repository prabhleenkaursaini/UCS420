# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhleenkaursaini/UCS420/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 2 — Python Data Structures (Lists, Tuples, Sets, Dictionaries)

# %% [markdown]
# 1. Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10 numbers in list now).
#
#   i. Print L

# %%
roll = input("Enter your roll number: ")
L = []
for digit in roll:
    L.append(int(digit) * 10)
print("Initial List:", L)
# Out:
# Enter your roll number: 1024170047
# Initial List: [10, 0, 20, 40, 10, 70, 0, 0, 40, 70]

# %% [markdown]
# ii. Add two numbers of your choice to L — one using append() and one using insert() at a specific position. Print L after each and explain in a comment what changed.

# %%
L.append(100)
print("After append:", L)
L.insert(2, 200)
print("After insert:", L)
# Out:
# After append: [10, 0, 20, 40, 10, 70, 0, 0, 40, 70, 100]
# After insert: [10, 0, 200, 20, 40, 10, 70, 0, 0, 40, 70, 100]

# %% [markdown]
# iii. Remove two elements from L — one using remove() and one using pop(). Print L after each.

# %%
L.remove(100)
print("After remove:", L)
L.pop(2)
print("After pop:", L)
# Out:
# After remove: [10, 0, 200, 20, 40, 10, 70, 0, 0, 40, 70]
# After pop: [10, 0, 20, 40, 10, 70, 0, 0, 40, 70]

# %% [markdown]
# iv. Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.

# %%
L.sort()
print("Ascending order:", L)
L.sort(reverse=True)
print("Descending order:", L)
# Out:
# Ascending order: [0, 0, 0, 10, 10, 20, 40, 40, 70, 70]
# Descending order: [70, 70, 40, 40, 20, 10, 10, 0, 0, 0]

# %% [markdown]
# v. Use slicing to print the first three elements and the last three elements of L in a single line each.

# %%
print("First three elements:", L[:3])
print("Last three elements:", L[-3:])
# Out:
# First three elements: [70, 70, 40]
# Last three elements: [0, 0, 0]

# %% [markdown]
# vi. Use list comprehension to create a new list containing only the elements of L that are greater than the average of L.

# %%
average = sum(L) / len(L)
new_list = [x for x in L if x > average]
print("Average:", average)
print("Elements greater than average:", new_list)
# Out:
# Average: 55.0
# Elements greater than average: [60, 70, 80, 90, 100]

# %% [markdown]
# 2. Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.

# %%
scores = tuple(L[:8])

print("Scores:", scores)
# Out:
# Scores: (10, 20, 30, 40, 50, 60, 70, 80)

# %% [markdown]
# i. Find the highest score and its index in the tuple, and the lowest score and how many times it appears.

# %%
highest = max(scores)
highest_index = scores.index(highest)
lowest = min(scores)
lowest_count = scores.count(lowest)
print("Highest score:", highest)
print("Index of highest score:", highest_index)
print("Lowest score:", lowest)
print("Number of times lowest appears:", lowest_count)
# Out:
# Highest score: 80
# Index of highest score: 7
# Lowest score: 10
# Number of times lowest appears: 1

# %% [markdown]
# ii. Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place — explain why in a one-line comment, referring to tuple immutability).

# %%
# Tuples are immutable, so they cannot be reversed in place.

reversed_scores = list(scores[::-1])

print("Reversed list:", reversed_scores)
# Out:
# Reversed list: [80, 70, 60, 50, 40, 30, 20, 10]

# %% [markdown]
# iii. Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present message if not.

# %%
score = int(input("Enter a score: "))

if score in scores:
    print("First occurrence index:", scores.index(score))
else:
    print("Score not present in tuple")
# Out:
# Enter a score: 30
# First occurrence index: 2

# %% [markdown]
# iv. Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error Python raises, and explain in one line why this happens and how it differs from a list.

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_620/1957282536.py in <cell line: 0>()
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Tuples are immutable, so their elements cannot be changed, unlike lists.

# %% [markdown]
# v. Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a single line of unpacking.

# %%
first, second, *remaining = scores
print("First score:", first)
print("Second score:", second)
print("Remaining scores:", remaining)
# Out:
# First score: 10
# Second score: 20
# Remaining scores: [30, 40, 50, 60, 70, 80]

# %% [markdown]
# 3. Set the random seed to your own roll number using random.seed(your_roll_number) before generating your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed produces a different list, so this cannot be copied from a classmate).

# %% [markdown]
# i. Generate a list of 100 random numbers between 100 and 900 (inclusive).

# %%
import random
random.seed(12345678)
numbers = []
for i in range(100):
    numbers.append(random.randint(100, 900))
print("Random numbers:")
print(numbers)
# Out:
# Random numbers:
# [837, 202, 748, 703, 334, 879, 358, 892, 720, 627, 700, 848, 621, 179, 883, 443, 225, 252, 458, 124, 606, 141, 887, 477, 838, 330, 594, 654, 145, 568, 326, 661, 230, 361, 170, 481, 137, 538, 381, 672, 748, 415, 491, 289, 834, 156, 228, 349, 322, 653, 513, 601, 279, 635, 697, 566, 867, 160, 481, 721, 327, 251, 206, 551, 247, 512, 342, 822, 312, 630, 387, 773, 320, 167, 504, 335, 738, 574, 805, 141, 764, 420, 750, 513, 519, 360, 483, 734, 819, 371, 823, 407, 838, 858, 304, 421, 539, 213, 656, 432]

# %% [markdown]
# ii. Count and print all odd numbers in the list.

# %%
odd_numbers = []
for num in numbers:
    if num % 2 != 0:
        odd_numbers.append(num)
print("Odd numbers:")
print(odd_numbers)
print("Count of odd numbers:", len(odd_numbers))
# Out:
# Odd numbers:
# [837, 703, 879, 627, 621, 179, 883, 443, 225, 141, 887, 477, 145, 661, 361, 481, 137, 381, 415, 491, 289, 349, 653, 513, 601, 279, 635, 697, 867, 481, 721, 327, 251, 551, 247, 387, 773, 167, 335, 805, 141, 513, 519, 483, 819, 371, 823, 407, 421, 539, 213]
# Count of odd numbers: 51

# %% [markdown]
# iii. Count and print all even numbers in the list.

# %%
even_numbers = []
for num in numbers:
    if num % 2 == 0:
        even_numbers.append(num)
print("Even numbers:")
print(even_numbers)
print("Count of even numbers:", len(even_numbers))
# Out:
# Even numbers:
# [202, 748, 334, 358, 892, 720, 700, 848, 252, 458, 124, 606, 838, 330, 594, 654, 568, 326, 230, 170, 538, 672, 748, 834, 156, 228, 322, 566, 160, 206, 512, 342, 822, 312, 630, 320, 504, 738, 574, 764, 420, 750, 360, 734, 838, 858, 304, 656, 432]
# Count of even numbers: 49

# %% [markdown]
# iv. Count and print all prime numbers in the list, and additionally build the actual list of prime numbers found using list comprehension.

# %%
def isPrime(num):
    if num < 2:
        return False
    for i in range(2, num):
        if num % i == 0:
            return False
    return True
prime_numbers = [num for num in numbers if isPrime(num)]
print("Prime numbers:")
print(prime_numbers)
print("Count of prime numbers:", len(prime_numbers))
# Out:
# Prime numbers:
# [179, 883, 443, 887, 661, 137, 491, 349, 653, 601, 251, 773, 167, 823, 421]
# Count of prime numbers: 15

# %% [markdown]
# v. Print the number that occurs most frequently in your list, and how many times it occurs.

# %%
most_frequent = numbers[0]
max_count = numbers.count(numbers[0])
for num in numbers:
    count = numbers.count(num)
    if count > max_count:
        max_count = count
        most_frequent = num
print("Most frequent number:", most_frequent)
print("Number of times it occurs:", max_count)
# Out:
# Most frequent number: 748
# Number of times it occurs: 2

# %% [markdown]
# 4. Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for each digit} and set B = {digit × 9 for each digit}. Print both sets.

# %%
digits = []
for digit in roll:
    digits.append(int(digit))
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}
print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 14, 49, 28}
# Set B: {0, 36, 9, 18, 63}

# %% [markdown]
# i. Find the union of A and B — all unique values across both sets.

# %%
union = A.union(B)
print("Union of A and B:", union)
# Out:
# Union of A and B: {0, 36, 7, 9, 14, 49, 18, 28, 63}

# %% [markdown]
# ii. Find the intersection of A and B — values common to both.

# %%
intersection = A.intersection(B)
print("Intersection of A and B:", intersection)
# Out:
# Intersection of A and B: {0}

# %% [markdown]
# iii. Find A − B and B − A separately (not combined) using difference(), and explain in one line how this differs from symmetric_difference().

# %%
A_difference_B = A.difference(B)
B_difference_A = B.difference(A)
print("A - B:", A_difference_B)
print("B - A:", B_difference_A)
# difference() gives values present in one set but not the other;
# symmetric_difference() gives values that are in either set but not both.
# Out:
# A - B: {49, 28, 14, 7}
# B - A: {9, 18, 36, 63}

# %% [markdown]
# iv. Find the symmetric difference of A and B.

# %%
symmetric_difference = A.symmetric_difference(B)
print("Symmetric difference:", symmetric_difference)
# Out:
# Symmetric difference: {7, 9, 14, 18, 28, 36, 49, 63}

# %% [markdown]
# v. Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().

# %%
print("Is A a subset of B?", A.issubset(B))
print("Is B a superset of A?", B.issuperset(A))
# Out:
# Is A a subset of B? False
# Is B a superset of A? False

# %% [markdown]
# vi. Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
X = int(input("Enter a value X: "))
A.discard(X)
print("Set A after removing X:", A)
# discard() is safer than remove() because it does not give an error if X is not present.
# Out:
# Enter a value X: 14
# Set A after removing X: {0, 7, 49, 28}

# %% [markdown]
# 5. Consider the following dictionary:
# my_dict = { "name": "<your name>", "roll_no": "<your roll number>", "branch": "<your branch>", "age": <your age>, "city": "<your home city>" }

# %%
my_dict = {
    "name": "Prabhleen Kaur Saini",
    "roll_no": "1024170047",
    "branch": "Computer Science and Engineering",
    "age": 20,
    "city": "Hoshiarpur"
}
print(my_dict)
# Out:
# {'name': 'Prabhleen Kaur Saini', 'roll_no': '1024170047', 'branch': 'Computer Science and Engineering', 'age': 20, 'city': 'Hoshiarpur'}

# %% [markdown]
# i. Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by hand — use pop() or dictionary comprehension so the code would work for any dictionary).

# %%
my_dict["location"] = my_dict.pop("city")
print(my_dict)
# Out:
# {'name': 'Prabhleen Kaur Saini', 'roll_no': '1024170047', 'branch': 'Computer Science and Engineering', 'age': 20, 'location': 'Hoshiarpur'}

# %% [markdown]
# ii. Add a new key “cgpa” with your CGPA as its value.

# %%
my_dict["cgpa"] = 8.5
print(my_dict)
# Out:
# {'name': 'Prabhleen Kaur Saini', 'roll_no': '1024170047', 'branch': 'Computer Science and Engineering', 'age': 20, 'location': 'Hoshiarpur', 'cgpa': 8.5}

# %% [markdown]
# iii. Update the value of “age” by increasing it by 1.

# %%
my_dict["age"] = my_dict["age"] + 1
print(my_dict)
# Out:
# {'name': 'Prabhleen Kaur Saini', 'roll_no': '1024170047', 'branch': 'Computer Science and Engineering', 'age': 21, 'location': 'Hoshiarpur', 'cgpa': 8.5}

# %% [markdown]
# iv. Delete the “branch” key using two different methods in two separate copies of the dictionary: once with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what does each return?).

# %%
dict_pop = my_dict.copy()
dict_del = my_dict.copy()
removed_branch = dict_pop.pop("branch")
print("After pop():", dict_pop)
print("Removed value:", removed_branch)
del dict_del["branch"]
print("After del:", dict_del)
# pop() removes the key and returns its value, while del only removes the key and returns nothing.
# Out:
# After pop(): {'name': 'Prabhleen Kaur Saini', 'roll_no': '1024170047', 'age': 21, 'location': 'Hoshiarpur', 'cgpa': 8.5}
# Removed value: Computer Science and Engineering
# After del: {'name': 'Prabhleen Kaur Saini', 'roll_no': '1024170047', 'age': 21, 'location': 'Hoshiarpur', 'cgpa': 8.5}

# %% [markdown]
# v. Iterate over your dictionary using .items() and print each key-value pair as “key → value”.

# %%
for key, value in my_dict.items():
    print(key, "→", value)
# Out:
# name → Prabhleen Kaur Saini
# roll_no → 1024170047
# branch → Computer Science and Engineering
# age → 21
# location → Hoshiarpur
# cgpa → 8.5

# %% [markdown]
# vi. Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence using the in keyword and print a safe fallback message instead of letting the program crash.

# %%
if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("Email is not present in the dictionary")
# Out:
# Email is not present in the dictionary

# %% [markdown]
# vii. Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details. Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win” when both dictionaries share a key.

# %%
friend_dict = {
    "name": "Rahul",
    "roll_no": "1024170048",
    "branch": "CSE",
    "age": 20,
    "city": "Delhi"
}
merged_dict = {**my_dict, **friend_dict}
print("Merged dictionary:", merged_dict)
# When both dictionaries have the same key, the value from the second dictionary wins.
# Out:
# Merged dictionary: {'name': 'Rahul', 'roll_no': '1024170048', 'branch': 'CSE', 'age': 20, 'location': 'Hoshiarpur', 'cgpa': 8.5, 'city': 'Delhi'}

# %% [markdown]
# viii. Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your original dictionary where the value is a string.

# %%
string_dict = {key: value for key, value in my_dict.items() if isinstance(value, str)}
print("Dictionary with string values:", string_dict)
# Out:
# Dictionary with string values: {'name': 'Prabhleen Kaur Saini', 'roll_no': '1024170047', 'branch': 'Computer Science and Engineering', 'location': 'Hoshiarpur'}
